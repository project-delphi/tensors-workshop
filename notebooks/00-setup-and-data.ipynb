# %% [markdown]
# # 00 · Setup and welcome / Preparación y bienvenida
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/project-delphi/tensors-workshop/blob/main/notebooks/00-setup-and-data.ipynb)
#
# <div style="height:3px;border-radius:2px;margin:1.4em 0 1.6em;background:linear-gradient(90deg,#0ea5e9,rgba(14,165,233,0))"></div>
#
# <span style="font:700 11px/1.6 ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;letter-spacing:.18em;color:#0ea5e9">SETUP · 5 MIN</span>
#
# ## Practise today / Practica hoy
#
# Name possible axes and predict a slice in the entry check.
#
# <div style="border-left:4px solid rgba(130,130,150,.5);background:rgba(130,130,150,.09);border-radius:0 8px 8px 0;padding:12px 16px;margin:1.2em 0 1.8em;font:400 14.5px/1.7 ui-sans-serif,system-ui,-apple-system,'Segoe UI',Roboto,sans-serif"><div style="font:700 10.5px/1 ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;letter-spacing:.18em;opacity:.62;margin-bottom:10px">🇪🇸 ESPAÑOL</div><div style="margin:0 0 0">Nombrar ejes posibles y predecir un corte en el diagnóstico inicial.</div></div>
#
# ## Explore later / Explora después
#
# After the entry check, revisit data-quality examples. Complete runtime setup before class.
#
# <div style="border-left:4px solid rgba(130,130,150,.5);background:rgba(130,130,150,.09);border-radius:0 8px 8px 0;padding:12px 16px;margin:1.2em 0 1.8em;font:400 14.5px/1.7 ui-sans-serif,system-ui,-apple-system,'Segoe UI',Roboto,sans-serif"><div style="font:700 10.5px/1 ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;letter-spacing:.18em;opacity:.62;margin-bottom:10px">🇪🇸 ESPAÑOL</div><div style="margin:0 0 0">Después del diagnóstico, repasar ejemplos de calidad de datos. Completar la preparación antes de clase.</div></div>
#
# Follow the core block immediately below. / Sigue el bloque esencial de abajo.

# %% [markdown]
# <!-- CORE-PATH -->
# ## Core path / Ruta esencial
#
# Entry check (3 min). Setup is pre-work. Start at **Core activity** below. Other exercises and explorers are optional.
#
# **You can:**
#
# - Name axes without confusing size with meaning.
# - Predict a selection's shape.
#
# <details>
# <summary>Español · Ruta y metas</summary>
#
# Diagnóstico inicial (3 min). Ejecuta la preparación antes del taller. Empieza en **Core activity** abajo. Los demás ejercicios y exploradores son opcionales.
#
# **Al terminar puedes:**
#
# - Nombrar ejes sin confundir tamaño y significado.
# - Predecir la forma de una selección.
#
# </details>

# %% [markdown]
# ### Core activity · Actividad esencial
#
# **Predict → Run → Explain → Check**
#
# 1. For X shaped (20, 8, 8), name two possible axis interpretations. Predict X[:, 3, 4].shape and name the remaining axis in each interpretation. What evidence separates batch from time?
# 2. Write your answer. No code or setup needed.
# 3. Compare your two interpretations with a partner.
# 4. Keep this answer for the exit check; do not revise it yet.
#
# <details>
# <summary>Español · Predice → Ejecuta → Explica → Comprueba</summary>
#
# 1. Para X de forma (20, 8, 8), da dos interpretaciones de sus ejes. Predice X[:, 3, 4].shape y nombra el eje restante en cada interpretación. ¿Qué evidencia distingue lote de tiempo?
# 2. Escribe tu respuesta. No necesitas código ni preparación.
# 3. Compara tus interpretaciones con otra persona.
# 4. Guarda esta respuesta para el cierre; aún no la cambies.
#
# </details>
#
# Answer / Respuesta: ___

# %% [markdown]
# ## Setup
#
# <div style="height:3px;border-radius:2px;margin:1.6em 0 1.9em;background:linear-gradient(90deg,#0ea5e9,rgba(14,165,233,0))"></div>
#
# Run this first. It installs and imports exactly what this notebook needs, and
# nothing more.
#
# <div style="border-left:4px solid rgba(130,130,150,.5);background:rgba(130,130,150,.09);border-radius:0 8px 8px 0;padding:15px 19px;margin:1.8em 0 2.2em;font:400 14.5px/1.8 ui-sans-serif,system-ui,-apple-system,'Segoe UI',Roboto,sans-serif"><div style="font:700 10.5px/1 ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;letter-spacing:.18em;opacity:.62;margin-bottom:10px">🇪🇸 ESPAÑOL</div>Ejecuta esto primero: instala e importa exactamente lo que este cuaderno necesita.</div>

# %%
# Section 05 decodes a real video and Colab does not reliably ship an
# ffmpeg backend, so install it now. Everything else below is already here.
# %pip install -q "imageio[ffmpeg]"

import numpy as np
import pandas as pd
from sklearn.datasets import load_digits, load_breast_cancer
from skimage import data
from scipy import signal
from scipy.linalg import lu, toeplitz

HOUSING = "https://raw.githubusercontent.com/ageron/handson-ml2/master/datasets/housing/housing.csv"
TAXIS   = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/taxis.csv"
FLIGHTS = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/flights.csv"

housing = pd.read_csv(HOUSING)
taxis   = pd.read_csv(TAXIS)
flights = pd.read_csv(FLIGHTS)
print(housing.shape, taxis.shape, flights.shape)   # (20640, 10) (6433, 14) (144, 3)

# Section 05's video is 5.9 MB, so don't pull it now -- just prove the backend
# imports and the host answers. Better to find out here than in two hours.
import imageio_ffmpeg, urllib.request
VIDEO_URL = ("https://upload.wikimedia.org/wikipedia/commons/1/1e/"
             "Tormenta_en_l%27Almadrava.webm")
req = urllib.request.Request(VIDEO_URL, headers={
    "User-Agent": "tensors-workshop/1.0 "
                  "(https://github.com/project-delphi/tensors-workshop)",
    "Range": "bytes=0-1023"})
got = urllib.request.urlopen(req, timeout=30).read()
# Assert rather than print the length: a proxy that ignores Range would quietly
# pull all 5.9 MB here and still look like a pass, which is the opposite of what
# this cell is for.
assert len(got) == 1024, f"expected a 1 KB range, got {len(got)} bytes"
print("1024 bytes of video reachable | ffmpeg", imageio_ffmpeg.get_ffmpeg_version())

# %% [markdown]
# ## Four words before we start / Cuatro palabras antes de empezar
#
# <div style="height:3px;border-radius:2px;margin:1.6em 0 1.9em;background:linear-gradient(90deg,#0ea5e9,rgba(14,165,233,0))"></div>
#
# You need no technical background here. Four words carry the rest.
#
# <div style="border-left:5px solid #0ea5e9;background:rgba(14,165,233,.10);border-radius:0 8px 8px 0;padding:18px 22px;margin:2.2em 0;font:400 15px/1.85 ui-sans-serif,system-ui,-apple-system,'Segoe UI',Roboto,sans-serif"><div style="font:700 11px/1 ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;letter-spacing:.18em;color:#0ea5e9;margin-bottom:11px">THE FOUR WORDS · LAS CUATRO PALABRAS</div><div style="margin:.55em 0"><b>Runtime</b> — the temporary computer Colab lends you.</div><div style="margin:.55em 0"><b>Dataset</b> — a collection of examples, much like a spreadsheet.</div><div style="margin:.55em 0"><b>Shape</b> — how the data is arranged. <code>(20640, 10)</code> is 20,640 rows and 10 columns.</div><div style="margin:.55em 0"><b>Axis</b> — one direction in the data: rows, or columns, or height, or colour.</div></div>
#
# A shape is the label on a box. It says how the contents are arranged. It never
# says what they mean.
#
# <div style="border-left:4px solid rgba(130,130,150,.5);background:rgba(130,130,150,.09);border-radius:0 8px 8px 0;padding:15px 19px;margin:1.8em 0 2.2em;font:400 14.5px/1.8 ui-sans-serif,system-ui,-apple-system,'Segoe UI',Roboto,sans-serif"><div style="font:700 10.5px/1 ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;letter-spacing:.18em;opacity:.62;margin-bottom:10px">🇪🇸 ESPAÑOL</div><ul style="margin:0;padding-left:1.2em"><li style="margin:.35em 0"><b>Runtime</b> — el computador temporal que Colab te presta.</li><li style="margin:.35em 0"><b>Dataset</b> — una colección de ejemplos, parecida a una hoja de cálculo.</li><li style="margin:.35em 0"><b>Forma (shape)</b> — cómo están organizados los datos. <code>(20640, 10)</code> son 20.640 filas y 10 columnas.</li><li style="margin:.35em 0"><b>Eje (axis)</b> — una dirección de los datos: filas, columnas, alto, color.</li></ul></div>
#
# <div style="border-left:4px solid rgba(130,130,150,.5);background:rgba(130,130,150,.09);border-radius:0 8px 8px 0;padding:15px 19px;margin:1.8em 0 2.2em;font:400 14.5px/1.8 ui-sans-serif,system-ui,-apple-system,'Segoe UI',Roboto,sans-serif"><div style="font:700 10.5px/1 ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;letter-spacing:.18em;opacity:.62;margin-bottom:10px">🇪🇸 ESPAÑOL</div>La forma es la etiqueta de una caja: dice cómo está organizado el contenido, nunca qué significa.</div>

# %% [markdown]
# ### What an axis looks like / Qué aspecto tiene un eje
#
# <div style="height:3px;border-radius:2px;margin:1.6em 0 1.9em;background:linear-gradient(90deg,#0ea5e9,rgba(14,165,233,0))"></div>
#
# Four words, one picture. The tensor below holds the numbers 0 to 59 arranged along three directions. Fixing one index at a time is all that indexing ever does — and each choice leaves a different shape behind.
#
# <img src="https://project-delphi.github.io/tensors-workshop/images/cube-00-axes.gif" alt="An animation of a tensor of shape 3 by 4 by 5, drawn as three stacked grids of numbers from 0 to 59. The first frame labels the three axes. The next three frames highlight, in turn, one whole plane, one row from every plane, and one column from every plane, with the resulting shape shown each time." style="max-width:100%;display:block;margin:2.2em auto;border-radius:10px">
#
# <div style="border-left:4px solid rgba(130,130,150,.5);background:rgba(130,130,150,.09);border-radius:0 8px 8px 0;padding:15px 19px;margin:1.8em 0 2.2em;font:400 14.5px/1.8 ui-sans-serif,system-ui,-apple-system,'Segoe UI',Roboto,sans-serif"><div style="font:700 10.5px/1 ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;letter-spacing:.18em;opacity:.62;margin-bottom:10px">🇪🇸 ESPAÑOL</div>Cuatro palabras, una imagen. El tensor de abajo contiene los números del 0 al 59 organizados en tres direcciones. Fijar un índice cada vez es todo lo que hace la indexación, y cada elección deja una forma distinta.</div>

# %% [markdown]
# ### Three indices, one number / Tres índices, un número
#
# <div style="height:3px;border-radius:2px;margin:1.6em 0 1.9em;background:linear-gradient(90deg,#0ea5e9,rgba(14,165,233,0))"></div>
#
# Indexing, drawn. Each frame fixes one more index: a plane, then a row, then a single cell. `T[1, 2, 3]` is `1 x 20 + 2 x 5 + 3` — the arithmetic that turns three numbers into one position, and it is checkable by eye.
#
# $$
# T[i, j, k]
# \quad\text{is stored at}\quad
# i \cdot n_1 n_2 + j \cdot n_2 + k
# $$
#
# Read it as: each index is multiplied by the size of everything to its right.
# For shape `(3, 4, 5)` that makes it $20i + 5j + k$, so `T[1, 2, 3]` is number
# $20 + 10 + 3 = 33$.
#
#
# <img src="https://project-delphi.github.io/tensors-workshop/images/cube-00-index.gif" alt="An animation narrowing from a 3 by 4 by 5 tensor to one number. The front plane is lifted away, then the second plane is highlighted, then one of its rows, then a single cell holding 33." style="max-width:100%;display:block;margin:2.2em auto;border-radius:10px">
#
# <div style="border-left:4px solid rgba(130,130,150,.5);background:rgba(130,130,150,.09);border-radius:0 8px 8px 0;padding:15px 19px;margin:1.8em 0 2.2em;font:400 14.5px/1.8 ui-sans-serif,system-ui,-apple-system,'Segoe UI',Roboto,sans-serif"><div style="font:700 10.5px/1 ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;letter-spacing:.18em;opacity:.62;margin-bottom:10px">🇪🇸 ESPAÑOL</div>La indexación, dibujada. Cada fotograma fija un índice más: un plano, luego una fila, luego una sola celda. <code>T[1, 2, 3]</code> es <code>1 x 20 + 2 x 5 + 3</code>: la aritmética que convierte tres números en una posición, y se puede comprobar a simple vista.</div>

# %% [markdown]
# ### A shape is the label on the box / La forma es la etiqueta de la caja
#
# <div style="height:3px;border-radius:2px;margin:1.6em 0 1.9em;background:linear-gradient(90deg,#0ea5e9,rgba(14,165,233,0))"></div>
#
# The same sixty numbers, arranged three ways. Nothing moves between the frames — only the brackets do. The last frame is the cost of that: 33 is still in there, and it has a different address in every shape. A shape says how the contents are arranged. It never says what they mean.
#
# $$
# (d_0,\; d_1,\; \ldots,\; d_{n-1})
# \qquad\longrightarrow\qquad
# \prod_{a=0}^{n-1} d_a \ \text{ numbers}
# $$
#
# Read it as: multiply a shape together and you get the count. $3 \times 4 \times 5$,
# $4 \times 15$ and $6 \times 10$ all come to 60, which is why the three
# arrangements hold the same numbers — and why a shape can change without a
# single number moving.
#
# <img src="https://project-delphi.github.io/tensors-workshop/images/cube-00-shape.gif" alt="An animation of sixty numbers shown first as a three by four by five pile of planes, then as a four by fifteen grid, then as a six by ten grid. The last frame places the pile beside the four by fifteen grid with the number 33 highlighted in each, at position 1, 2, 3 in one and position 2, 3 in the other." style="max-width:100%;display:block;margin:2.2em auto;border-radius:10px">
#
# <div style="border-left:4px solid rgba(130,130,150,.5);background:rgba(130,130,150,.09);border-radius:0 8px 8px 0;padding:15px 19px;margin:1.8em 0 2.2em;font:400 14.5px/1.8 ui-sans-serif,system-ui,-apple-system,'Segoe UI',Roboto,sans-serif"><div style="font:700 10.5px/1 ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;letter-spacing:.18em;opacity:.62;margin-bottom:11px">🇪🇸 ESPAÑOL</div>Los mismos sesenta números, ordenados de tres maneras. Entre un fotograma y otro no se mueve nada: solo cambian los corchetes. El último fotograma muestra el costo: el 33 sigue ahí, y tiene una dirección distinta en cada forma. Una forma dice cómo está ordenado el contenido; nunca dice qué significa.</div>

# %%
#@title ⏸️ Step through the animations / Recorre las animaciones { display-mode: 'form' }

# Plumbing, not a lesson. The animations above loop forever and a GIF cannot
# be paused — so this fetches the same frames and hands them over one at a
# time, at whatever pace you read at.
# Plomería, no una lección: trae los mismos fotogramas y los entrega de uno en
# uno, al ritmo al que leas.

import io
import urllib.request

import ipywidgets as widgets
from IPython.display import display
from PIL import Image

gif_urls = [
    "https://project-delphi.github.io/tensors-workshop/images/cube-00-axes.gif",
    "https://project-delphi.github.io/tensors-workshop/images/cube-00-index.gif",
    "https://project-delphi.github.io/tensors-workshop/images/cube-00-shape.gif",
]


def gif_frames(url):
    """Every frame of an animated GIF, as PNG bytes."""
    with urllib.request.urlopen(url, timeout=30) as response:
        gif = Image.open(io.BytesIO(response.read()))
    out = []
    try:
        while True:
            buffer = io.BytesIO()
            gif.convert("RGB").save(buffer, format="PNG")
            out.append(buffer.getvalue())
            gif.seek(gif.tell() + 1)
    except EOFError:
        pass
    return out


try:
    gif_cache = {url: gif_frames(url) for url in gif_urls}
except Exception as error:  # offline, or the site is down
    print("EN: could not reach the site, so there are no frames to step "
          "through.", error)
    print("ES: no se pudo acceder al sitio, así que no hay fotogramas que "
          "recorrer.", error)
else:
    gif_pick = widgets.Dropdown(
        options=[(url.rsplit("/", 1)[1], url) for url in gif_urls],
        description="Animation / Animación:",
        style={"description_width": "180px"},
    )
    gif_step = widgets.IntSlider(
        min=1, max=len(gif_cache[gif_urls[0]]), value=1,
        description="Frame / Fotograma:",
        style={"description_width": "180px"},
        continuous_update=False,
    )
    gif_prev = widgets.Button(description="◀ Prev")
    gif_next = widgets.Button(description="Next ▶")
    # An Image widget, deliberately, and never widgets.Output: a payload
    # leaving an Output widget makes nbclient wait out the whole cell timeout
    # (see scripts/test_notebooks.py). This one is a plain bytes trait.
    gif_view = widgets.Image(format="png",
                             layout=widgets.Layout(max_width="100%"))

    def gif_show(*_):
        frames = gif_cache[gif_pick.value]
        gif_step.max = len(frames)
        gif_view.value = frames[min(gif_step.value, len(frames)) - 1]

    def gif_bump(delta):
        def click(_):
            frames = gif_cache[gif_pick.value]
            gif_step.value = (gif_step.value - 1 + delta) % len(frames) + 1
        return click

    gif_prev.on_click(gif_bump(-1))
    gif_next.on_click(gif_bump(+1))
    gif_pick.observe(gif_show, names="value")
    gif_step.observe(gif_show, names="value")
    gif_show()

    display(widgets.VBox([
        gif_pick,
        widgets.HBox([gif_prev, gif_step, gif_next]),
        gif_view,
    ]))

# %% [markdown]
# ## Where each dataset comes from / De dónde viene cada conjunto de datos
#
# <div style="height:3px;border-radius:2px;margin:1.6em 0 1.9em;background:linear-gradient(90deg,#0ea5e9,rgba(14,165,233,0))"></div>
#
# Check the ingredients before you cook. A missing one is cheap to fix now and
# expensive to fix halfway through.
#
# We use **real data** wherever real structure matters, because real data carries
# what clean classroom examples hide:
#
# - missing values — a measurement was never recorded;
# - wildly different scales — one column in small decimals, another in thousands;
# - columns that never change — **zero-variance** columns, later on.
#
# A few sections use small synthetic examples on purpose, and say so when they do.
#
# <div style="border-left:4px solid rgba(130,130,150,.5);background:rgba(130,130,150,.09);border-radius:0 8px 8px 0;padding:15px 19px;margin:1.8em 0 2.2em;font:400 14.5px/1.8 ui-sans-serif,system-ui,-apple-system,'Segoe UI',Roboto,sans-serif"><div style="font:700 10.5px/1 ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;letter-spacing:.18em;opacity:.62;margin-bottom:10px">🇪🇸 ESPAÑOL</div><ul style="margin:0;padding-left:1.2em"><li style="margin:.35em 0">valores faltantes — una medición no fue registrada;</li><li style="margin:.35em 0">escalas muy distintas — una columna en decimales pequeños y otra en miles;</li><li style="margin:.35em 0">columnas que no cambian — columnas de <b>varianza cero</b>, más adelante.</li></ul></div>
#
# <div style="border-left:4px solid rgba(130,130,150,.5);background:rgba(130,130,150,.09);border-radius:0 8px 8px 0;padding:15px 19px;margin:1.8em 0 2.2em;font:400 14.5px/1.8 ui-sans-serif,system-ui,-apple-system,'Segoe UI',Roboto,sans-serif"><div style="font:700 10.5px/1 ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;letter-spacing:.18em;opacity:.62;margin-bottom:10px">🇪🇸 ESPAÑOL</div>Revisa los ingredientes antes de cocinar. Preferimos <b>datos reales</b> cuando la estructura del mundo real importa. Algunas secciones usan ejemplos sintéticos a propósito, y lo dicen.</div>

# %% [markdown]
# ### Included in the libraries / Incluidos en las librerías
#
# Already packaged with Python's libraries. No download.
#
# <div style="border-left:4px solid rgba(130,130,150,.5);background:rgba(130,130,150,.09);border-radius:0 8px 8px 0;padding:15px 19px;margin:1.8em 0 2.2em;font:400 14.5px/1.8 ui-sans-serif,system-ui,-apple-system,'Segoe UI',Roboto,sans-serif"><div style="font:700 10.5px/1 ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;letter-spacing:.18em;opacity:.62;margin-bottom:10px">🇪🇸 ESPAÑOL</div>Ya vienen con las librerías de Python. No necesitan descarga.</div>
#
# | Dataset / Conjunto | What it is / Qué es | Shape / Forma |
# |---|---|---|
# | `load_breast_cancer()` | 569 real samples, 30 measurements each / 569 muestras reales, 30 mediciones cada una | `(569, 30)` |
# | `load_digits()` | 1,797 real handwritten digits / 1.797 dígitos manuscritos reales | `(1797, 8, 8)` |
# | `data.camera()`, `data.astronaut()` | Real photographs / Fotografías reales | `(512, 512)`, `(512, 512, 3)` |
# | `data.immunohistochemistry()`, `data.cell()` | Real histology and microscopy / Histología y microscopía reales | `(512, 512, 3)`, `(660, 550)` |

# %% [markdown]
# ### Downloaded at the start / Descargados al comienzo
#
# These need the network. They take seconds.
#
# <div style="border-left:4px solid rgba(130,130,150,.5);background:rgba(130,130,150,.09);border-radius:0 8px 8px 0;padding:15px 19px;margin:1.8em 0 2.2em;font:400 14.5px/1.8 ui-sans-serif,system-ui,-apple-system,'Segoe UI',Roboto,sans-serif"><div style="font:700 10.5px/1 ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;letter-spacing:.18em;opacity:.62;margin-bottom:10px">🇪🇸 ESPAÑOL</div>Necesitan conexión a internet y tardan segundos.</div>
#
# | Dataset / Conjunto | What it is / Qué es | Used for / Se usará para |
# |---|---|---|
# | California Housing | 20,640 real housing districts / 20.640 distritos reales de vivienda | Pseudoinverse and least squares / Pseudoinversa y mínimos cuadrados (§07) |
# | NYC Taxi Trips | 6,433 real taxi trips / 6.433 viajes reales de taxi | Tensor factorization / Factorización tensorial (§10) |
# | Airline Passengers | 144 months of real passenger counts / 144 meses de conteos reales de pasajeros | Recursion and forecasting / Recursión y pronóstico (§08) |

# %% [markdown]
# ### Downloaded later / Descargados más adelante
#
# The full video and audio arrive only when their own sections need them. Here we
# check that the video source answers.
#
# <div style="border-left:4px solid rgba(130,130,150,.5);background:rgba(130,130,150,.09);border-radius:0 8px 8px 0;padding:15px 19px;margin:1.8em 0 2.2em;font:400 14.5px/1.8 ui-sans-serif,system-ui,-apple-system,'Segoe UI',Roboto,sans-serif"><div style="font:700 10.5px/1 ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;letter-spacing:.18em;opacity:.62;margin-bottom:10px">🇪🇸 ESPAÑOL</div>El video y el audio completos llegan solo cuando sus secciones los necesitan. Aquí solo comprobamos que la fuente responda.</div>
#
# | Dataset / Conjunto | What it is / Qué es | Used for / Se usará para |
# |---|---|---|
# | Storm video | 24 seconds, 720 frames / 24 segundos, 720 fotogramas | Video pipeline design / Diseño de pipeline de video (§05) |
# | Voice recording | Five-second CC0 voice sample / Grabación de voz CC0 de cinco segundos | Audio denoising / Reducción de ruido de audio (NB11) |

# %% [markdown]
# ### Did Setup work? / ¿Funcionó el Setup?
#
# <div style="border-left:5px solid #0ea5e9;background:rgba(14,165,233,.10);border-radius:0 8px 8px 0;padding:18px 22px;margin:2.2em 0;font:400 15px/1.85 ui-sans-serif,system-ui,-apple-system,'Segoe UI',Roboto,sans-serif"><div style="font:700 11px/1 ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;letter-spacing:.18em;color:#0ea5e9;margin-bottom:11px">YOU SHOULD SEE · DEBES VER</div><div style="margin:.4em 0"><code>(20640, 10) (6433, 14) (144, 3)</code></div><div style="margin:.4em 0">and a line beginning <code>1024 bytes of video reachable</code></div></div>
#
# Both of those, and the downloads and the video connection are ready.
#
# <div style="border-left:4px solid rgba(130,130,150,.5);background:rgba(130,130,150,.09);border-radius:0 8px 8px 0;padding:15px 19px;margin:1.8em 0 2.2em;font:400 14.5px/1.8 ui-sans-serif,system-ui,-apple-system,'Segoe UI',Roboto,sans-serif"><div style="font:700 10.5px/1 ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;letter-spacing:.18em;opacity:.62;margin-bottom:10px">🇪🇸 ESPAÑOL</div>Si ves <code>(20640, 10) (6433, 14) (144, 3)</code> y una línea que empieza por <code>1024 bytes of video reachable</code>, las descargas y la conexión al video están listas.</div>

# %% [markdown]
# ## See it, not just its shape / Míralo, no te quedes solo con la forma
#
# <div style="height:3px;border-radius:2px;margin:1.6em 0 1.9em;background:linear-gradient(90deg,#0ea5e9,rgba(14,165,233,0))"></div>
#
# A shape check can pass while the data is wrong. A table can have the right
# number of rows and one empty column. A download can arrive truncated.
#
# So look at it. The next cell asks three questions.
#
# <div style="border-left:5px solid #0ea5e9;background:rgba(14,165,233,.10);border-radius:0 8px 8px 0;padding:18px 22px;margin:2.2em 0;font:400 15px/1.85 ui-sans-serif,system-ui,-apple-system,'Segoe UI',Roboto,sans-serif"><div style="font:700 11px/1 ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;letter-spacing:.18em;color:#0ea5e9;margin-bottom:11px">THREE VISUAL CHECKS · TRES COMPROBACIONES VISUALES</div><div style="margin:.55em 0"><span style="display:inline-block;width:22px;height:22px;border-radius:50%;background:#0ea5e9;color:#fff;text-align:center;font:700 12px/22px ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;margin-right:9px">1</span>Do the California housing locations look geographically plausible?</div><div style="margin:.55em 0"><span style="display:inline-block;width:22px;height:22px;border-radius:50%;background:#0ea5e9;color:#fff;text-align:center;font:700 12px/22px ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;margin-right:9px">2</span>Does the taxi-fare distribution look measured, rather than empty?</div><div style="margin:.55em 0"><span style="display:inline-block;width:22px;height:22px;border-radius:50%;background:#0ea5e9;color:#fff;text-align:center;font:700 12px/22px ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;margin-right:9px">3</span>Does airline traffic change sensibly over time?</div></div>
#
# <div style="border-left:4px solid rgba(130,130,150,.5);background:rgba(130,130,150,.09);border-radius:0 8px 8px 0;padding:15px 19px;margin:1.8em 0 2.2em;font:400 14.5px/1.8 ui-sans-serif,system-ui,-apple-system,'Segoe UI',Roboto,sans-serif"><div style="font:700 10.5px/1 ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;letter-spacing:.18em;opacity:.62;margin-bottom:10px">🇪🇸 ESPAÑOL</div>Un conjunto puede tener la forma esperada y aun así estar mal: una columna vacía, un archivo incompleto. Por eso miramos. La celda siguiente responde tres preguntas: <b>1 ·</b> ¿las ubicaciones de vivienda son geográficamente razonables? <b>2 ·</b> ¿las tarifas de taxi parecen mediciones reales y no una columna vacía? <b>3 ·</b> ¿el tráfico aéreo cambia de forma razonable con el tiempo?</div>

# %% [markdown]
# ## Predict first / Predice primero
#
# <div style="height:3px;border-radius:2px;margin:1.6em 0 1.9em;background:linear-gradient(90deg,#0ea5e9,rgba(14,165,233,0))"></div>
#
# Someone says the following. **Decide whether they are right before you
# reveal anything** — commit to one answer, then open the check.
#
# <div style="border-left:5px solid #0ea5e9;background:rgba(14,165,233,0.1);border-radius:0 8px 8px 0;padding:18px 22px;margin:2.2em 0;font:400 15px/1.85 ui-sans-serif,system-ui,-apple-system,'Segoe UI',Roboto,sans-serif"><div style="font:700 11px/1 ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;letter-spacing:.18em;color:#0ea5e9;margin-bottom:11px">THE CLAIM · LA AFIRMACIÓN</div><div style="margin:.55em 0">&ldquo;The table downloaded with <b>exactly the shape the docs promise</b>, so nothing is missing.&rdquo;</div></div>
#
# A prediction you have committed to is worth more than one you keep
# adjusting as the answer appears.
#
# <div style="border-left:4px solid rgba(130,130,150,.5);background:rgba(130,130,150,.09);border-radius:0 8px 8px 0;padding:15px 19px;margin:1.8em 0 2.2em;font:400 14.5px/1.8 ui-sans-serif,system-ui,-apple-system,'Segoe UI',Roboto,sans-serif"><div style="font:700 10.5px/1 ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;letter-spacing:.18em;opacity:.62;margin-bottom:10px">🇪🇸 ESPAÑOL</div>Alguien afirma que, como la tabla se descargó con <b>exactamente la forma prometida</b>, no falta ningún dato. Decide si tiene razón <b>antes</b> de revelar la comprobación.</div>

# %%
#@title 🤔 Predict: does the right shape mean the data is complete? / Predice: ¿una forma correcta significa que los datos están completos? — run me / ejecútame { display-mode: 'form' }

# --- counterexample / contraejemplo (tested in tests/test_teaching_materials.py) ---
import numpy as np

# California housing, as Exercise 2 finds it: the promised shape, and 207
# rows whose total_bedrooms was never recorded.
pred_table = np.zeros((20640, 10))
pred_table[:207, 4] = np.nan

assert pred_table.shape == (20640, 10)
assert np.isnan(pred_table).sum() == 207
assert not np.isfinite(pred_table).all()
# --- end counterexample / fin del contraejemplo ---

import ipywidgets as widgets
from IPython.display import display

# --- how the question is laid out / cómo se presenta la pregunta ---
# Radio buttons rather than a dropdown. Four bilingual answers squeezed into
# one 640px line were hard to read, and a dropdown hides three of them until
# you open it -- the wrong shape for a question whose whole point is weighing
# the options against each other. One per line, with room around them.
# Botones de opción en vez de un desplegable: una respuesta por línea.
import contextlib
import html as pred_html
import io

PRED_ACCENT = "#0ea5e9"
PRED_SANS = "ui-sans-serif,system-ui,-apple-system,'Segoe UI',Roboto,sans-serif"
PRED_MONO = "ui-monospace,SFMono-Regular,Menlo,Consolas,monospace"


def pred_tag(text):
    """A small EN / ES marker, in words rather than in colour alone."""
    return (f'<span style="font:700 10px/1 {PRED_MONO};letter-spacing:.16em;'
            f'color:{PRED_ACCENT};opacity:.8;margin-right:9px;'
            f'vertical-align:.12em">{text}</span>')


def pred_is_measurement(line):
    """True for a printed reading, false for a sentence.

    A reading wants monospace and tight rows so the numbers line up under one
    another; a sentence wants prose type and room. The two used to share one
    13px monospace column, which is most of why the reveal read as a wall.
    """
    if ":" not in line:
        return False
    tail = line.rsplit(":", 1)[1].strip()
    return bool(tail) and (tail[0].isdigit()
                           or tail[0] in "[(-+."
                           or tail.startswith(("True", "False", "nan", "inf")))


def pred_panel(text):
    """The reveal, laid out instead of printed.

    Exactly the same words: `check_prediction` still prints, and this catches
    what it printed and gives it typography. EN and ES stay written out as
    tags rather than becoming a colour, because a reader who cannot see the
    colour still has to be able to tell the two apart.
    """
    blocks = []
    for line in text.rstrip("\n").split("\n"):
        stripped = line.strip()
        if not stripped:
            blocks.append('<div style="height:12px"></div>')
        elif stripped.startswith(("EN:", "ES:")):
            tag, body = stripped[:2], stripped[3:].strip()
            blocks.append(
                f'<p style="margin:.55em 0;font:400 15px/1.8 {PRED_SANS}">'
                f'{pred_tag(tag)}{pred_html.escape(body)}</p>')
        elif pred_is_measurement(stripped):
            blocks.append(
                f'<div style="font:400 13.5px/2.0 {PRED_MONO};'
                f'white-space:pre-wrap">{pred_html.escape(stripped)}</div>')
        else:
            blocks.append(
                f'<p style="margin:.55em 0;font:600 15.5px/1.75 {PRED_SANS}">'
                f'{pred_html.escape(stripped)}</p>')
    return (f'<div style="border-left:4px solid {PRED_ACCENT};'
            f'background:rgba(130,130,150,.08);border-radius:0 10px 10px 0;'
            f'padding:16px 20px;margin:.4em 0 0">{"".join(blocks)}</div>')


def pred_render(choice, reveal):
    """Run the check, catch what it prints, and show it laid out."""
    caught = io.StringIO()
    with contextlib.redirect_stdout(caught):
        check_prediction(choice, reveal)
    display(widgets.HTML(pred_panel(caught.getvalue())))

pred_choice = widgets.RadioButtons(
    options=[
        ("— choose one / elige una —", None),
        ("Right — the shape is the check / Correcto — la forma es la comprobación", "shape_enough"),
        ("Wrong — a shape check cannot see missing values / Incorrecto — una forma no ve valores faltantes", "shape_blind"),
        ("Only wrong for text columns / Solo es falso en columnas de texto", "text_only"),
    ],
    value=None,
    description="",
    layout=widgets.Layout(width="auto", margin="0 0 6px 0"),
)

pred_reveal = widgets.Checkbox(
    value=False,
    description="Show me the answer / Muéstrame la respuesta",
    indent=False,
    layout=widgets.Layout(margin="10px 0 4px 0"),
)

def check_prediction(choice, reveal):
    if choice is None:
        print("Choose an answer first / Elige una respuesta primero.")
        return

    if not reveal:
        print("Answer saved / Respuesta guardada.")
        print("Tick the box above when you are ready / Marca la casilla de arriba\n      cuando quieras.".replace("\n      ", " "))
        return

    print("Shape / Forma:", pred_table.shape, "— exactly as promised / exactamente la prometida")
    print("Missing values / Valores faltantes:", int(np.isnan(pred_table).sum()))
    print("All finite? / ¿Todo finito?", bool(np.isfinite(pred_table).all()))
    print()
    if choice == "shape_blind":
        print("You were right / Acertaste.")
    else:
        print("You were wrong — read on / Te equivocaste; sigue leyendo.")
    print()
    print("EN: the shape check passes and 207 values are still missing. A shape counts positions; it never looks inside them.")
    print("ES: la comprobación de forma pasa y aun así faltan 207 valores. Una forma cuenta posiciones; nunca mira dentro de ellas.")

# The one <style> block in these notebooks, and the markdown rule does not
# cover it. ipywidgets gives no way to set the space between radio options
# from Python, and this is *widget output*, not a markdown cell: Colab strips
# <style> from markdown -- which is why every box in these notebooks is
# inline-styled -- but renders it in an output, the same path pandas' own
# Styler uses. Scoped to one added class so it can reach nothing else, and if
# it is ever dropped the options still work, just closer together.
pred_choice.add_class("pred-radio")

display(widgets.HTML(
    "<style>"
    ".pred-radio .widget-radio-box label{display:flex;align-items:flex-start;"
    "margin:0 0 13px;font:400 15px/1.6 " + PRED_SANS + "}"
    ".pred-radio input[type=radio]{flex:none;margin:4px 11px 0 0;"
    "transform:scale(1.15)}"
    "</style>"
))

pred_output = widgets.interactive_output(
    pred_render,
    {"choice": pred_choice, "reveal": pred_reveal},
)

pred_heading = widgets.HTML(
    f'<div style="font:700 11px/1.6 {PRED_MONO};letter-spacing:.18em;'
    f'color:{PRED_ACCENT};margin:2px 0 12px">'
    f'YOUR PREDICTION \u00b7 TU PREDICCI\u00d3N</div>'
)

display(widgets.VBox(
    [pred_heading, pred_choice, pred_reveal, pred_output],
    layout=widgets.Layout(padding="2px 0 14px 0"),
))

# %%
#@title 📊 Three visual checks / Tres comprobaciones visuales — run me / ejecútame { display-mode: 'form' }

import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 3, figsize=(12, 3.2))

sc = axes[0].scatter(housing["longitude"], housing["latitude"],
                      c=housing["median_house_value"], cmap="viridis", s=4)
axes[0].set_title("Housing locations / Ubicaciones de vivienda")
fig.colorbar(sc, ax=axes[0], fraction=0.046)

axes[1].hist(taxis["fare"].dropna(), bins=30, color="#4C72B0")
axes[1].set_title("Taxi fares / Tarifas de taxi")
axes[1].set_xlabel("fare ($) / tarifa ($)")

by_year = flights.groupby("year")["passengers"].sum()
axes[2].plot(by_year.index, by_year.values, marker="o", color="#55A868")
axes[2].set_title("Passengers by year / Pasajeros por año")

fig.suptitle(
    "Quick visual check of real data / Revisión visual rápida de datos reales"
)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Exercise 1 — read a shape as a sentence / Ejercicio 1 — lee una forma como una frase
#
# <div style="height:3px;border-radius:2px;margin:1.6em 0 1.9em;background:linear-gradient(90deg,#0ea5e9,rgba(14,165,233,0))"></div>
#
# A shape is useful only once you can say what each number counts.
#
# <div style="border-left:5px solid #0ea5e9;background:rgba(14,165,233,.10);border-radius:0 8px 8px 0;padding:18px 22px;margin:2.2em 0;font:400 15px/1.85 ui-sans-serif,system-ui,-apple-system,'Segoe UI',Roboto,sans-serif"><div style="font:700 11px/1 ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;letter-spacing:.18em;color:#0ea5e9;margin-bottom:11px">WORKED EXAMPLE · EJEMPLO RESUELTO</div><span style="font:600 13px/1 ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;background:rgba(14,165,233,.14);border:1px solid rgba(14,165,233,.4);border-radius:999px;padding:4px 11px;white-space:nowrap">(569, 30)</span><div style="margin-top:10px">569 samples, with 30 measurements for each sample.</div><div style="margin-top:6px;opacity:.8">569 muestras, con 30 mediciones para cada muestra.</div></div>
#
# Now do the same for the datasets below.
#
# <div style="border-left:4px solid rgba(130,130,150,.5);background:rgba(130,130,150,.09);border-radius:0 8px 8px 0;padding:15px 19px;margin:1.8em 0 2.2em;font:400 14.5px/1.8 ui-sans-serif,system-ui,-apple-system,'Segoe UI',Roboto,sans-serif"><div style="font:700 10.5px/1 ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;letter-spacing:.18em;opacity:.62;margin-bottom:10px">🇪🇸 ESPAÑOL</div>Una forma solo sirve si puedes explicar qué cuenta cada número. Usa el ejemplo y describe con palabras las formas siguientes.</div>

# %%
# TODO 1 / TAREA 1
# EN: Load the breast-cancer dataset and print bc.data.shape.
#     Then explain what each axis counts.
# ES: Carga el conjunto de cáncer de mama e imprime bc.data.shape.
#     Después explica qué cuenta cada eje.
#
# TODO 2 / TAREA 2
# EN: Print the shapes of load_digits().images and
#     data.immunohistochemistry().
#     Both have three axes. Do those axes mean the same thing?
# ES: Imprime las formas de load_digits().images y
#     data.immunohistochemistry().
#     Ambos tienen tres ejes. ¿Significan lo mismo esos ejes?

# %%
#@title Solution / Solución — try it yourself first / inténtalo primero { display-mode: 'form' }

bc = load_breast_cancer()
digits_shape = load_digits().images.shape
histology_shape = data.immunohistochemistry().shape

print("Breast-cancer data / Datos de cáncer:", bc.data.shape)
print("EN: 569 samples × 30 measurements.")
print("ES: 569 muestras × 30 mediciones.")
print()

print("Digit images / Imágenes de dígitos:", digits_shape)
print("EN: 1,797 images × 8 pixels high × 8 pixels wide.")
print("ES: 1.797 imágenes × 8 píxeles de alto × 8 píxeles de ancho.")
print()

print("Histology image / Imagen histológica:", histology_shape)
print("EN: 512 pixels high × 512 pixels wide × 3 colour channels.")
print("ES: 512 píxeles de alto × 512 píxeles de ancho × 3 canales de color.")
print()

print("EN: Same number of axes does NOT mean the axes have the same meaning.")
print("ES: Tener el mismo número de ejes NO significa que los ejes tengan el mismo significado.")

# %% [markdown]
# <details>
# <summary><strong>Why this solution works · Por qué funciona esta solución</strong></summary>
#
# The skill is translating a shape into meaning. Memorising numbers is not.
#
# - `(569, 30)` — a spreadsheet: 569 sample rows × 30 measurement columns.
# - `(1797, 8, 8)` — a stack of images: image × height × width.
# - `(512, 512, 3)` — one colour image: height × width × colour.
#
# Two of those have three axes and describe nothing alike. Shape says how the
# data is arranged. The dataset says what the axes mean.
#
# <div style="border-left:4px solid rgba(130,130,150,.5);background:rgba(130,130,150,.09);border-radius:0 8px 8px 0;padding:15px 19px;margin:1.8em 0 2.2em;font:400 14.5px/1.8 ui-sans-serif,system-ui,-apple-system,'Segoe UI',Roboto,sans-serif"><div style="font:700 10.5px/1 ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;letter-spacing:.18em;opacity:.62;margin-bottom:10px">🇪🇸 ESPAÑOL</div>Traducir una forma a significado es la habilidad; memorizar números no lo es. <code>(569, 30)</code> es una hoja de cálculo, <code>(1797, 8, 8)</code> una pila de imágenes y <code>(512, 512, 3)</code> una imagen a color. La forma dice cómo están organizados los datos; el conjunto dice qué significan los ejes.</div>
#
# </details>

# %% [markdown]
# ## Exercise 2 — two clues in real data / Ejercicio 2 — dos pistas en datos reales
#
# <div style="height:3px;border-radius:2px;margin:1.6em 0 1.9em;background:linear-gradient(90deg,#0ea5e9,rgba(14,165,233,0))"></div>
#
# Real data is rarely clean. No statistics needed here — two plain questions.
#
# <div style="border-left:5px solid #0ea5e9;background:rgba(14,165,233,.10);border-radius:0 8px 8px 0;padding:18px 22px;margin:2.2em 0;font:400 15px/1.85 ui-sans-serif,system-ui,-apple-system,'Segoe UI',Roboto,sans-serif"><div style="font:700 11px/1 ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;letter-spacing:.18em;color:#0ea5e9;margin-bottom:11px">FIND BOTH · ENCUENTRA LAS DOS</div><div style="margin:.55em 0"><span style="display:inline-block;width:22px;height:22px;border-radius:50%;background:#0ea5e9;color:#fff;text-align:center;font:700 12px/22px ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;margin-right:9px">1</span>Is anything <b>missing</b> in the housing table?</div><div style="margin:.55em 0"><span style="display:inline-block;width:22px;height:22px;border-radius:50%;background:#0ea5e9;color:#fff;text-align:center;font:700 12px/22px ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;margin-right:9px">2</span>At what <b>hour</b> do the most taxi trips start?</div></div>
#
# <div style="border-left:4px solid rgba(130,130,150,.5);background:rgba(130,130,150,.09);border-radius:0 8px 8px 0;padding:15px 19px;margin:1.8em 0 2.2em;font:400 14.5px/1.8 ui-sans-serif,system-ui,-apple-system,'Segoe UI',Roboto,sans-serif"><div style="font:700 10.5px/1 ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;letter-spacing:.18em;opacity:.62;margin-bottom:10px">🇪🇸 ESPAÑOL</div>Los datos reales rara vez están limpios. Sin estadística avanzada: <b>1 ·</b> ¿falta algún dato en la tabla de vivienda? <b>2 ·</b> ¿a qué hora empiezan más viajes de taxi?</div>

# %%
# TODO 3 / TAREA 3
# EN: Print housing.shape and count the missing values in each column.
#     Which column has missing values? How many?
# ES: Imprime housing.shape y cuenta los valores faltantes de cada columna.
#     ¿Qué columna tiene valores faltantes? ¿Cuántos?
#
# TODO 4 / TAREA 4
# EN: Convert taxis["pickup"] to datetime, extract the hour,
#     and find the hour with the most trips.
# ES: Convierte taxis["pickup"] a fecha y hora, extrae la hora
#     y encuentra la hora con mayor cantidad de viajes.

# %%
#@title Solution / Solución — try it yourself first / inténtalo primero { display-mode: 'form' }

print("Housing shape / Forma de vivienda:", housing.shape)

missing = housing.isnull().sum()
missing = missing[missing > 0]
print("\nMissing values / Valores faltantes:")
print(missing)

hour = pd.to_datetime(taxis["pickup"]).dt.hour
busiest_hour = int(hour.value_counts().idxmax())

print("\nBusiest pickup hour / Hora con más recogidas:", busiest_hour)
print("EN: The busiest hour is 18:00 (6:00 p.m.) in this dataset.")
print("ES: La hora con más recogidas es 18:00 (6:00 p. m.) en este conjunto.")

print("\nEN: Missing values are not an error in Python; they are a property of the real data that we must handle.")
print("ES: Los valores faltantes no son un error de Python; son una característica de los datos reales que debemos tratar.")

# %% [markdown]
# <details>
# <summary><strong>Why this solution works · Por qué funciona esta solución</strong></summary>
#
# `housing.shape == (20640, 10)` is 20,640 rows and 10 columns. An Excel table.
#
# The check finds **207 missing values in `total_bedrooms`**. For those rows that
# one measurement is unavailable, and before any matrix arithmetic you have to
# decide what to do with them.
#
# A taxi timestamp holds several facts at once. Pull the **hour** out of it and
# trips group by time of day. Here, hour `18` has the most pickups.
#
# <div style="border-left:4px solid rgba(130,130,150,.5);background:rgba(130,130,150,.09);border-radius:0 8px 8px 0;padding:15px 19px;margin:1.8em 0 2.2em;font:400 14.5px/1.8 ui-sans-serif,system-ui,-apple-system,'Segoe UI',Roboto,sans-serif"><div style="font:700 10.5px/1 ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;letter-spacing:.18em;opacity:.62;margin-bottom:10px">🇪🇸 ESPAÑOL</div><code>(20640, 10)</code> son 20.640 filas y 10 columnas. La comprobación encuentra <b>207 valores faltantes en <code>total_bedrooms</code></b>: antes de cualquier cálculo matricial hay que decidir qué hacer con esas filas. De una fecha y hora de taxi se extrae la <b>hora</b>, y así los viajes se agrupan por momento del día. Aquí gana la hora <code>18</code>.</div>
#
# </details>

# %% [markdown]
# ## How these notebooks work / Cómo funcionan estos cuadernos
#
# <div style="height:3px;border-radius:2px;margin:1.6em 0 1.9em;background:linear-gradient(90deg,#0ea5e9,rgba(14,165,233,0))"></div>
#
# Every notebook is **self-contained**. Open 07 without running 00–06 and it
# still works.
#
# That is why the same download address shows up in more than one notebook. The
# repetition is deliberate.
#
# Notebooks are stored with **no saved outputs**. Every number, plot and widget
# you see was made by your own Colab session.
#
# If your result differs from the expected one, that is a clue. Chase it.
#
# <div style="border-left:4px solid rgba(130,130,150,.5);background:rgba(130,130,150,.09);border-radius:0 8px 8px 0;padding:15px 19px;margin:1.8em 0 2.2em;font:400 14.5px/1.8 ui-sans-serif,system-ui,-apple-system,'Segoe UI',Roboto,sans-serif"><div style="font:700 10.5px/1 ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;letter-spacing:.18em;opacity:.62;margin-bottom:10px">🇪🇸 ESPAÑOL</div>Cada cuaderno es <b>autónomo</b>: puedes abrir el 07 sin ejecutar antes 00–06. Por eso una misma dirección de descarga aparece en varios cuadernos; la repetición es intencional. Se guardan <b>sin resultados</b>: todo lo que ves lo genera tu propia sesión de Colab. Si tu resultado difiere del esperado, es una pista — investígala.</div>

# %% [markdown]
# ## What just happened / Qué acaba de pasar
#
# <div style="height:3px;border-radius:2px;margin:1.6em 0 1.9em;background:linear-gradient(90deg,#0ea5e9,rgba(14,165,233,0))"></div>
#
# You are ready to start. You also used four habits that come back all day.
#
# <div style="border-left:5px solid #0ea5e9;background:rgba(14,165,233,.10);border-radius:0 8px 8px 0;padding:18px 22px;margin:2.2em 0;font:400 15px/1.85 ui-sans-serif,system-ui,-apple-system,'Segoe UI',Roboto,sans-serif"><div style="font:700 11px/1 ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;letter-spacing:.18em;color:#0ea5e9;margin-bottom:11px">FOUR HABITS · CUATRO HÁBITOS</div><div style="margin:.55em 0"><span style="display:inline-block;width:22px;height:22px;border-radius:50%;background:#0ea5e9;color:#fff;text-align:center;font:700 12px/22px ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;margin-right:9px">1</span><b>Check the environment</b> — the data is reachable, the tools are here.</div><div style="margin:.55em 0"><span style="display:inline-block;width:22px;height:22px;border-radius:50%;background:#0ea5e9;color:#fff;text-align:center;font:700 12px/22px ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;margin-right:9px">2</span><b>Read a shape as meaning</b> — <code>(20640, 10)</code> is rows and columns, not two numbers.</div><div style="margin:.55em 0"><span style="display:inline-block;width:22px;height:22px;border-radius:50%;background:#0ea5e9;color:#fff;text-align:center;font:700 12px/22px ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;margin-right:9px">3</span><b>Look at the data</b> — a plot catches what a shape check cannot.</div><div style="margin:.55em 0"><span style="display:inline-block;width:22px;height:22px;border-radius:50%;background:#0ea5e9;color:#fff;text-align:center;font:700 12px/22px ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;margin-right:9px">4</span><b>Expect real data to be imperfect</b> — missing values are to be handled, not ignored.</div></div>
#
# Before a model learns anything from data, you learn what the data holds and how
# it is arranged.
#
# <div style="border-left:4px solid rgba(130,130,150,.5);background:rgba(130,130,150,.09);border-radius:0 8px 8px 0;padding:15px 19px;margin:1.8em 0 2.2em;font:400 14.5px/1.8 ui-sans-serif,system-ui,-apple-system,'Segoe UI',Roboto,sans-serif"><div style="font:700 10.5px/1 ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;letter-spacing:.18em;opacity:.62;margin-bottom:10px">🇪🇸 ESPAÑOL</div>Ya puedes empezar. Cuatro hábitos que volverán todo el día: <b>1 ·</b> comprobar el entorno, <b>2 ·</b> leer una forma como significado, <b>3 ·</b> mirar los datos, <b>4 ·</b> esperar que los datos reales sean imperfectos.<br><br>Antes de que un modelo aprenda de los datos, aprende tú qué contienen y cómo están organizados.</div>

# %% [markdown]
# <div style="height:3px;border-radius:2px;margin:1.4em 0 1.6em;background:linear-gradient(90deg,#0ea5e9,rgba(14,165,233,0))"></div>
#
# ## Done with this section
#
# <div style="border-left:4px solid rgba(130,130,150,.5);background:rgba(130,130,150,.09);border-radius:0 8px 8px 0;padding:12px 16px;margin:1.2em 0 1.8em;font:400 14.5px/1.7 ui-sans-serif,system-ui,-apple-system,'Segoe UI',Roboto,sans-serif"><div style="font:700 10.5px/1 ui-monospace,SFMono-Regular,Menlo,Consolas,monospace;letter-spacing:.18em;opacity:.62;margin-bottom:10px">🇪🇸 ESPAÑOL</div><div style="margin:0 0 0"><b>Fin de esta sección.</b></div></div>
#
# Next up: **01 · What a tensor is** — [open in Colab](https://colab.research.google.com/github/project-delphi/tensors-workshop/blob/main/notebooks/01-what-a-tensor-is.ipynb).
#
# [← Back to the workshop site](https://project-delphi.github.io/tensors-workshop/) · [All notebooks](https://project-delphi.github.io/tensors-workshop/notebooks.html) · [Handbook](https://project-delphi.github.io/tensors-workshop/tensors_workshop_plan_with_quizzes.html)
